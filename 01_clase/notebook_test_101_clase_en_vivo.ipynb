# %% [markdown]
# <a href="https://colab.research.google.com/github/Andru-1987/data_science_95320/blob/master/01_clase/notebook_test_101_clase_en_vivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Soy un encabezado
# ---
# |col1|col2|col3|
# |:---:|:---: |:---:|
# |row1|row1|row1|
# |row2|row2|row2|

# %%
nombre = "Anderson"
nombre
# Out:
# 'Anderson'
